# %% [markdown]
# ### Model Parameter 설정

# %%
from dotenv import load_dotenv
import os
# .env 파일을 불러와서 환경 변수로 설정
load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
print(OPENAI_API_KEY[:5])
# Out:
# sk-sv

# %% [markdown]
# ### 1) 모델 클래스 유형

# %% [markdown]
# #### OpenAI

# %%
from langchain_openai import OpenAI

# model을 지정하지 않아도 실행되는 이유는 LangChain이 내부적으로 기본값을 설정함
llm = OpenAI()
print(llm.model_name)  # 기본 모델 확인

result = llm.invoke("한국의 대표적인 관광지 3군데를 추천해 주세요.")
print(type(result))
print(result)
# Out:
# gpt-3.5-turbo-instruct
# <class 'str'>
#
#
# 1. 경복궁
# 2. 부산 해운대해수욕장
# 3. 제주도 용머리해안

# %% [markdown]
# #### ChatOpenAI

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

model = ChatOpenAI(model="gpt-4o-mini")
print(model.model_name)

chat_prompt = ChatPromptTemplate.from_messages([
    ("system", "이 시스템은 여행 전문가입니다."),
    ("human", "{user_input}"),
])

chain = chat_prompt | model
result = chain.invoke({"user_input": "안녕하세요? 한국의 대표적인 관광지 3군데를 추천해 주세요."})

print(type(result))
print(result.content)
# Out:
# gpt-4o-mini
# <class 'langchain_core.messages.ai.AIMessage'>
# 안녕하세요! 한국의 대표적인 관광지 3군데를 추천해 드리겠습니다.
#
# 1. **경복궁 (Gyeongbokgung Palace)**:
#    서울의 중심부에 위치한 경복궁은 조선왕조의 주요 궁궐 중 하나로, 아름다운 전통 건축물과 정원이 매력적입니다. 매일 열리는 수문장 교대식은 관광객들에게 인기 있는 볼거리입니다. 궁 안에 있는 국립민속박물관과 국립고궁박물관도 함께 방문해 볼 수 있습니다.
#
# 2. **제주도 (Jeju Island)**:
#    제주도는 한국의 대표적인 여행지로, 독특한 자연경관과 다양한 관광명소가 있습니다. 한라산, 성산일출봉, 만장굴 등 자연경관이 아름답고, 제주도만의 독특한 음식과 문화를 경험할 수 있습니다. 해변과 수많은 워터스포츠도 매력적입니다.
#
# 3. **부산 (Busan)**:
#    대한민국 제2의 도시 부산은 아름다운 해안선과 활기 넘치는 항구 도시입니다. 해운대와 광안리 해수욕장은 여름철에 특히 인기가 많으며, 자갈치 시장에서는 신선한 해산물을 맛볼 수 있습니다. 태종대와 부산타워에서의 전망도 놓치지 마세요.
#
# 이 세 곳은 한국의 다양한 매력을 느낄 수 있는 관광지들이니 꼭 방문해 보시길 추천합니다!

# %% [markdown]
# #### Groq

# %%
from dotenv import load_dotenv
import os
# .env 파일을 불러와서 환경 변수로 설정
load_dotenv()

GROQ_API_KEY = os.getenv("GROQ_API_KEY")
print(GROQ_API_KEY[:5])
# Out:
# gsk_D

# %%
from groq import Groq

llm = Groq(api_key=GROQ_API_KEY)
print(llm)  # 기본 모델 확인

try:
    # Groq API 호출
    chat_completion = llm.chat.completions.create(
        messages=[            
            {
                "role": "user",
                "content": "한국의 대표적인 관광지 3군데를 추천해 주세요.",
            }
        ],
        model="meta-llama/llama-4-scout-17b-16e-instruct", # model명은 변경하지 말아 줘  
        temperature=0.7,
        max_tokens=300,
        top_p=1,
        stop=None,
        stream=False,
    )

    converted_message = chat_completion.choices[0].message.content
    print(converted_message)

except Exception as e:
    print(f"Error calling Groq API: {e}")
# Out:
# <groq.Groq object at 0x0000010FD2C58BF0>
# 1.  **경복궁**: 서울에 위치한 경복궁은 한국의 대표적인 궁궐 중 하나입니다. 조선시대 왕실의 정궁으로, 아름다운 건축물과 정원으로 유명합니다. 경복궁의 역사와 문화를 경험할 수 있는 곳입니다. 경복궁은 1395년에 지어졌으며, 조선시대 왕실의 정궁으로 사용되었습니다. 경복궁은 한국의 역사와 문화를 대표하는 건축물 중 하나입니다.
#
# 2.  **제주도**: 제주도는 한국의 남쪽에 위치한 아름다운 섬입니다. 제주도는 아름다운 해변, 화산 지층, 그리고 전통 마을로 유명합니다. 제주도는 자연과 문화를 경험할 수 있는 곳입니다. 제주도는 한국의 대표적인 관광지 중 하나입니다. 제주도는 아름다운 자연 경관과 다양한 문화를 가지고 있습니다.
#
# 3.  **부산 해운대**: 부산에 위치한 해운대는 한국의 대표적인 해변 중 하나입니다. 해운대는 아름다운 해변, 밤바다, 그리고 다양한 해양 활동으로 유명합니다. 해운대는 여름철에 많은 관광객이 찾는 곳입니다. 해운대는 부산의 대표적인 관광지 중 하나입니다. 해운대는 아름다운 자연 경관과 다양한 활동을 가지고 있습니다.
