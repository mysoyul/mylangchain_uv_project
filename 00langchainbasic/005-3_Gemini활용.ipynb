# %%
# uv add langchain-google-genai

# %%
from dotenv import load_dotenv
import os
# .env 파일을 불러와서 환경 변수로 설정
load_dotenv()

GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
print(GOOGLE_API_KEY[:4])
# Out:
# AIza

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
    
# API 키 설정
# os.environ["GOOGLE_API_KEY"] = "your-google-api-key"

# 모델 초기화
llm = ChatGoogleGenerativeAI(
    #model="gemini-1.5-flash",
    #model="gemini-2.5-pro",
    model="gemini-2.5-flash-lite",
    #model="gemini-3-pro-preview",
    temperature=0.3    
)

# 프롬프트 설정
prompt = ChatPromptTemplate.from_messages([
    ("system", "당신은 AI 전문가입니다."),
    ("human", "{topic}은(는) 무엇인가요?")
])

# 체인 실행
chain = prompt | llm
response = chain.invoke({"topic": "LangChain과 LangGraph"})

print(" Google Gemini Response:")
print(response.content)
# Out:
#  Google Gemini Response:
# ## LangChain과 LangGraph: AI 애플리케이션 개발의 핵심 도구
#
# AI 전문가로서 LangChain과 LangGraph는 최신 AI 애플리케이션 개발에서 매우 중요한 두 가지 도구라고 말씀드릴 수 있습니다. 각각의 역할과 특징을 자세히 설명해 드리겠습니다.
#
# ### LangChain: LLM 기반 애플리케이션 개발을 위한 프레임워크
#
# **LangChain**은 **대규모 언어 모델(LLM)을 활용한 애플리케이션 개발을 간소화하는 프레임워크**입니다. LLM 자체는 강력하지만, 실제 복잡한 애플리케이션을 구축하기 위해서는 다양한 구성 요소와 상호 작용이 필요합니다. LangChain은 이러한 복잡성을 추상화하고 개발자가 LLM을 더 쉽게 통합하고 활용할 수 있도록 다양한 도구와 추상화를 제공합니다.
#
# **LangChain의 주요 특징 및 구성 요소:**
#
# *   **모듈성:** LangChain은 다양한 모듈로 구성되어 있어, 개발자는 필요한 부분만 선택적으로 사용할 수 있습니다. 주요 모듈은 다음과 같습니다.
#     *   **Models:** 다양한 LLM 제공업체(OpenAI, Hugging Face 등)와의 연동을 지원합니다.
#     *   **Prompts:** LLM에 전달할 프롬프트를 관리하고 최적화하는 기능을 제공합니다.
#     *   **Chains:** 여러 LLM 호출이나 다른 구성 요소를 순차적으로 연결하여 복잡한 작업을 수행합니다. 예를 들어, 질문에 대한 답변을 생성하기 전에 관련 정보를 검색하는 체인을 만들 수 있습니다.
#     *   **Indexes:** 외부 데이터를 LLM이 이해하고 활용할 수 있도록 구조화하고 검색하는 기능을 제공합니다. 문서 로딩, 텍스트 분할, 벡터 저장소 연동 등이 포함됩니다.
#     *   **Agents:** LLM이 특정 도구(검색 엔진, 계산기, API 등)를 사용하여 스스로 결정을 내리고 작업을 수행하도록 합니다. LLM은 사용자의 요청을 이해하고 어떤 도구를 사용해야 할지, 어떻게 사용해야 할지를 결정합니다.
#     *   **Memory:** LLM이 이전 대화 내용을 기억하고 이를 바탕으로 일관성 있는 응답을 생성하도록 합니다.
# *   **추상화:** LLM 제공업체나 데이터 소스에 대한 세부 사항을 추상화하여 개발자가 특정 기술에 덜 종속적인 코드를 작성할 수 있도록 합니다.
# *   **유연성:** 다양한 LLM, 데이터 소스, 도구와의 통합을 지원하여 광범위한 애플리케이션 구축이 가능합니다.
# *   **커뮤니티:** 활발한 커뮤니티를 통해 다양한 예제, 튜토리얼, 라이브러리를 얻을 수 있습니다.
#
# **LangChain을 사용하는 이유:**
#
# *   LLM 기반 애플리케이션 개발 속도 향상
# *   복잡한 LLM 워크플로우 구축 용이
# *   다양한 외부 도구 및 데이터 소스와의 통합 간편화
# *   재사용 가능한 구성 요소 활용
#
# ### LangGraph: 복잡한 상태 기반 워크플로우를 위한 그래프 라이브러리
#
# **LangGraph**는 **LangChain의 확장으로, 복잡한 상태 기반 워크플로우를 그래프 형태로 모델링하고 실행하기 위한 라이브러리**입니다. 특히, 여러 단계에 걸쳐 상태가 변경되고, 각 단계에서 조건부 로직이나 반복이 필요한 애플리케이션에 적합합니다. LangGraph는 LangChain의 체인 개념을 확장하여, 더 동적이고 복잡한 실행 흐름을 관리할 수 있도록 합니다.
#
# **LangGraph의 주요 특징:**
#
# *   **그래프 기반 모델링:** 애플리케이션의 워크플로우를 노드(단계)와 엣지(전환)로 구성된 그래프로 표현합니다. 각 노드는 특정 작업을 수행하는 함수(예: LLM 호출, 데이터 처리)를 나타냅니다.
# *   **상태 관리:** 워크플로우의 각 단계에서 상태(데이터, 변수 등)를 명확하게 관리하고 전달합니다. 이는 이전 단계의 결과를 다음 단계에서 활용하는 데 필수적입니다.
# *   **조건부 로직 및 분기:** 그래프의 엣지에 조건을 부여하여 특정 상태에 따라 다른 경로로 실행 흐름을 분기할 수 있습니다.
# *   **반복 및 루프:** 특정 조건을 만족할 때까지 동일한 노드나 노드 그룹을 반복 실행하는 루프를 구현할 수 있습니다.
# *   **병렬 실행 (향후 지원 예정):** 여러 작업을 동시에 실행하여 효율성을 높이는 기능도 고려되고 있습니다.
# *   **LangChain과의 통합:** LangChain의 다양한 모듈(LLM, Tools 등)을 LangGraph의 노드로 쉽게 통합하여 사용할 수 있습니다.
#
# **LangGraph를 사용하는 이유:**
#
# *   **복잡한 상태 전이 로직 구현:** 여러 단계에 걸쳐 상태가 복잡하게 변하는 애플리케이션을 직관적으로 모델링할 수 있습니다.
# *   **동적이고 유연한 워크플로우:** 조건부 로직, 분기, 반복 등을 통해 동적인 실행 흐름을 쉽게 구현할 수 있습니다.
# *   **디버깅 및 시각화 용이:** 그래프 구조는 워크플로우의 흐름을 시각적으로 이해하고 디버깅하는 데 도움을 줍니다.
# *   **에이전트 및 멀티 에이전트 시스템 구축:** 여러 에이전트가 서로 상호 작용하고 상태를 공유하는 복잡한 시스템을 구축하는 데 강력한 도구입니다.
#
# ### LangChain vs LangGraph: 언제 무엇을 사용할까?
#
# *   **LangChain:**
#     *   단순한 LLM 호출, 텍스트 생성, 정보 검색 등 **비교적 선형적인 워크플로우**를 구축할 때.
#     *   LLM을 다양한 도구나 데이터 소스와 **간단하게 통합**하고 싶을 때.
#     *   **빠르게 프로토타이핑**하고 LLM 기반 애플리케이션의 기본 구조를 만들 때.
#
# *   **LangGraph:**
#     *   **여러 단계에 걸쳐 상태가 중요하고, 복잡한 조건부 로직, 분기, 반복**이 필요한 워크플로우를 구축할 때.
#     *   **에이전트 간의 복잡한 상호 작용**이나 **멀티 에이전트 시스템**을 설계할 때.
#     *   **게임 AI, 시뮬레이션, 복잡한 의사 결정 시스템** 등 동적인 상태 관리가 필수적인 애플리케이션을 개발할 때.
#     *   LangChain으로 구축된 워크플로우를 **더욱 동적이고 복잡하게 확장**하고 싶을 때.
#
# **결론적으로,**
#
# LangChain은 LLM 기반 애플리케이션 개발의 **기반을 다지는 프레임워크**이며, LangGraph는 LangChain의 기능을 확장하여 **더욱 복잡하고 동적인 상태 기반 워크플로우를 효과적으로 구축할 수 있도록 돕는 라이브러리**입니다. 이 두 도구를 함께 사용하면 최신 AI 기술을 활용하여 강력하고 정교한 애플리케이션을 개발하는 데 큰 도움을 받을 수 있습니다.

# %% [markdown]
# #### Gemini 모델별 특징
#
# * gemini-1.5-flash: 빠른 응답, 일반적인 작업에 적합
# * gemini-2.5-pro: 더 정확하고 복잡한 추론 작업
# * gemini-pro-vision: 이미지 처리 및 멀티모달 작업

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate, PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# API 키 설정
# os.environ["GOOGLE_API_KEY"] = "your-google-api-key"

# 기본 모델 설정
llm = ChatGoogleGenerativeAI(
    #model="gemini-1.5-flash",
    #model="gemini-2.5-pro",
    model="gemini-2.5-flash-lite",
    temperature=0.7
)

print("=" * 50)
print("예제 1: 기본 대화형 챗봇")
print("=" * 50)

# 대화형 프롬프트
chat_prompt = ChatPromptTemplate.from_messages([
    ("system", "당신은 친근하고 도움이 되는 AI 어시스턴트입니다."),
    ("human", "{user_input}")
])

chat_chain = chat_prompt | llm | StrOutputParser()
response1 = chat_chain.invoke({"user_input": "파이썬으로 리스트를 정렬하는 방법은?"})
print("응답:", response1)

print("\n" + "=" * 50)
print("예제 2: JSON 구조화 출력")
print("=" * 50)

json_prompt = PromptTemplate(
    template="""
다음 정보를 JSON 형태로 변환하세요:
{company_info}

형식: {{"name": "회사명", "year": "연도", "location": "위치"}}
""",
    input_variables=["company_info"]
)

json_chain = json_prompt | llm | StrOutputParser()
company_text = "네이버는 1999년에 설립된 한국의 IT 기업이며 본사는 경기도 성남에 있습니다."
response2 = json_chain.invoke({"company_info": company_text})
print("JSON 결과:", response2)
# Out:
# ==================================================
# 예제 1: 기본 대화형 챗봇
# ==================================================
# 응답: 파이썬에서 리스트를 정렬하는 방법은 크게 두 가지가 있습니다.
#
# 1.  **`sort()` 메서드 사용:**
#     *   리스트 자체를 **제자리에서(in-place)** 정렬합니다. 즉, 원래 리스트가 변경됩니다.
#     *   반환값은 `None` 입니다.
#     *   기본적으로 오름차순으로 정렬합니다.
#
#     ```python
#     my_list = [3, 1, 4, 1, 5, 9, 2, 6]
#     my_list.sort()
#     print(my_list)  # 출력: [1, 1, 2, 3, 4, 5, 6, 9]
#     ```
#
# 2.  **`sorted()` 함수 사용:**
#     *   정렬된 **새로운 리스트를 반환**합니다. 원래 리스트는 변경되지 않습니다.
#     *   어떤 반복 가능한(iterable) 객체에도 사용할 수 있습니다 (리스트, 튜플, 문자열 등).
#     *   기본적으로 오름차순으로 정렬합니다.
#
#     ```python
#     my_list = [3, 1, 4, 1, 5, 9, 2, 6]
#     new_list = sorted(my_list)
#     print(my_list)     # 출력: [3, 1, 4, 1, 5, 9, 2, 6] (원래 리스트는 그대로)
#     print(new_list)    # 출력: [1, 1, 2, 3, 4, 5, 6, 9] (새로운 정렬된 리스트)
#     ```
#
# ---
#
# ### 추가 옵션: 역순 정렬
#
# 두 방법 모두 `reverse` 매개변수를 사용하여 역순으로 정렬할 수 있습니다.
#
# *   **`sort(reverse=True)`**
#
#     ```python
#     my_list = [3, 1, 4, 1, 5, 9, 2, 6]
#     my_list.sort(reverse=True)
#     print(my_list)  # 출력: [9, 6, 5, 4, 3, 2, 1, 1]
#     ```
#
# *   **`sorted(iterable, reverse=True)`**
#
#     ```python
#     my_list = [3, 1, 4, 1, 5, 9, 2, 6]
#     new_list_desc = sorted(my_list, reverse=True)
#     print(new_list_desc)  # 출력: [9, 6, 5, 4, 3, 2, 1, 1]
#     ```
#
# ---
#
# ### 추가 옵션: 사용자 정의 정렬 기준 (`key` 매개변수)
#
# `key` 매개변수를 사용하면 정렬 기준을 지정할 수 있습니다. `key`는 함수를 인자로 받으며, 리스트의 각 요소를 이 함수에 통과시켜 반환된 값을 기준으로 정렬합니다.
#
# *   **`sort(key=function)`**
#
#     ```python
#     words = ["apple", "banana", "cherry", "date"]
#     words.sort(key=len)  # 각 단어의 길이를 기준으로 정렬
#     print(words)  # 출력: ['date', 'apple', 'banana', 'cherry']
#     ```
#
# *   **`sorted(iterable, key=function)`**
#
#     ```python
#     words = ["apple", "banana", "cherry", "date"]
#     sorted_words = sorted(words, key=len)
#     print(sorted_words)  # 출력: ['date', 'apple', 'banana', 'cherry']
#     ```
#
#     람다(lambda) 함수를 사용하여 간단한 함수를 즉석에서 만들 수도 있습니다.
#
#     ```python
#     students = [
#         {'name': 'Alice', 'grade': 85},
#         {'name': 'Bob', 'grade': 92},
#         {'name': 'Charlie', 'grade': 78}
#     ]
#     students.sort(key=lambda student: student['grade']) # 성적을 기준으로 오름차순 정렬
#     print(students)
#     # 출력: [{'name': 'Charlie', 'grade': 78}, {'name': 'Alice', 'grade': 85}, {'name': 'Bob', 'grade': 92}]
#
#     sorted_by_name = sorted(students, key=lambda student: student['name']) # 이름을 기준으로 오름차순 정렬
#     print(sorted_by_name)
#     # 출력: [{'name': 'Alice', 'grade': 85}, {'name': 'Bob', 'grade': 92}, {'name': 'Charlie', 'grade': 78}]
#     ```
#
# ---
#
# **어떤 방법을 선택해야 할까요?**
#
# *   원래 리스트를 변경해도 괜찮고, 메모리를 절약하고 싶다면 **`sort()` 메서드**를 사용하세요.
# *   원래 리스트를 그대로 유지하고, 정렬된 새로운 리스트가 필요하다면 **`sorted()` 함수**를 사용하세요.
# *   리스트가 아닌 다른 반복 가능한 객체 (튜플 등)를 정렬해야 한다면 **`sorted()` 함수**만 사용할 수 있습니다.
#
# 궁금한 점이 있다면 언제든지 다시 물어보세요! 😊
#
# ==================================================
# 예제 2: JSON 구조화 출력
# ==================================================
# JSON 결과: ```json
# {
#   "name": "네이버",
#   "year": "1999",
#   "location": "경기도 성남"
# }
# ```

# %%
print("\n" + "=" * 50)
print("예제 3: 번역 체인")
print("=" * 50)

translate_prompt = ChatPromptTemplate.from_template(
    "다음 텍스트를 {target_language}로 번역하세요: {text}"
)

translate_chain = translate_prompt | llm | StrOutputParser()
original = "Hello, how are you today?"
translated = translate_chain.invoke({
    "text": original, 
    "target_language": "한국어"
})
print("번역 결과:", translated)

print("\n" + "=" * 50)
print("예제 4: 감정 분석")
print("=" * 50)

emotion_prompt = ChatPromptTemplate.from_template("""
텍스트: {text}
감정을 분석하고 [긍정/부정/중립]과 1-10점수를 매기세요.
""")

emotion_chain = emotion_prompt | llm | StrOutputParser()
test_text = "오늘 프로젝트가 성공적으로 완료되어서 정말 기쁩니다!"
emotion_result = emotion_chain.invoke({"text": test_text})
print("감정 분석:", emotion_result)

print("\n" + "=" * 50)
print("예제 5: 코드 생성")
print("=" * 50)

code_prompt = ChatPromptTemplate.from_template("""
{language}로 {task} 기능을 구현하는 간단한 코드를 작성하세요.
""")

code_chain = code_prompt | llm | StrOutputParser()
code_result = code_chain.invoke({
    "language": "Python",
    "task": "두 숫자의 최대공약수를 구하는"
})
print("생성된 코드:")
print(code_result)

print("\n" + "=" * 50)
print("예제 6: 창의적 콘텐츠 생성")
print("=" * 50)
# Out:
# ==================================================
# 예제 3: 번역 체인
# ==================================================
# 번역 결과: "안녕하세요, 오늘 기분은 어떠신가요?"
#
# ==================================================
# 예제 4: 감정 분석
# ==================================================
# 감정 분석: **감정 분석:**
#
# *   **감정:** [긍정]
# *   **점수:** 9/10
#
# **설명:**
#
# "성공적으로 완료되어서 정말 기쁩니다!"라는 문구는 명확하게 긍정적인 감정을 나타냅니다. '성공적으로 완료'라는 결과와 '정말 기쁩니다'라는 직접적인 표현은 높은 수준의 만족감과 행복감을 전달합니다. 따라서 긍정적인 감정으로 분류되며, '정말'이라는 부사가 감정을 더욱 강조하기 때문에 10점 만점에 9점으로 평가하는 것이 적절합니다.
#
# ==================================================
# 예제 5: 코드 생성
# ==================================================
# 생성된 코드:
# ## Python으로 두 숫자의 최대공약수(GCD) 구하기
#
# 두 숫자의 최대공약수(GCD)를 구하는 가장 간단하고 효율적인 방법 중 하나는 **유클리드 호제법**을 이용하는 것입니다.
#
# **유클리드 호제법이란?**
#
# 두 양의 정수 $a$와 $b$ ($a > b$)에 대해, $a$를 $b$로 나눈 나머지를 $r$이라고 할 때, $a$와 $b$의 최대공약수는 $b$와 $r$의 최대공약수와 같습니다. 이 과정을 나머지가 0이 될 때까지 반복하면, 마지막으로 0이 아닌 나머지가 바로 두 수의 최대공약수가 됩니다.
#
# ### 코드 구현
#
# ```python
# def gcd(a, b):
#   """
#   두 양의 정수 a와 b의 최대공약수를 유클리드 호제법을 이용하여 구합니다.
#
#   Args:
#     a: 첫 번째 양의 정수
#     b: 두 번째 양의 정수
#
#   Returns:
#     a와 b의 최대공약수
#   """
#   while b:  # b가 0이 아닐 동안 반복
#     a, b = b, a % b  # a를 b로, b를 a % b (나머지)로 업데이트
#   return a
#
# # 예시 사용
# num1 = 48
# num2 = 18
#
# result = gcd(num1, num2)
# print(f"{num1}과 {num2}의 최대공약수는 {result}입니다.")
#
# num3 = 101
# num4 = 103
#
# result2 = gcd(num3, num4)
# print(f"{num3}과 {num4}의 최대공약수는 {result2}입니다.")
# ```
#
# ### 코드 설명
#
# 1.  **`def gcd(a, b):`**: `gcd`라는 이름의 함수를 정의하고, 두 개의 인자 `a`와 `b`를 받습니다.
# 2.  **`while b:`**: `b`가 0이 아닐 동안 루프를 실행합니다. 유클리드 호제법에서 나머지가 0이 되면 알고리즘이 종료되기 때문입니다.
# 3.  **`a, b = b, a % b`**: 이 부분이 유클리드 호제법의 핵심입니다.
#     *   `a % b`는 `a`를 `b`로 나눈 나머지를 계산합니다.
#     *   파이썬의 **튜플 언패킹(tuple unpacking)** 기능을 사용하여 `a`에는 이전 `b`의 값이, `b`에는 `a % b`의 결과가 동시에 할당됩니다.
# 4.  **`return a`**: `while` 루프가 종료되면 `b`는 0이 되고, 이때 `a`의 값이 두 수의 최대공약수가 됩니다.
#
# ### 다른 방법 (Python 3.5 이상)
#
# Python 3.5 버전부터는 `math` 모듈에 `gcd` 함수가 내장되어 있어 더 간단하게 사용할 수 있습니다.
#
# ```python
# import math
#
# num1 = 48
# num2 = 18
#
# result = math.gcd(num1, num2)
# print(f"{num1}과 {num2}의 최대공약수는 {result}입니다.")
# ```
#
# 이 방법은 코드를 더 간결하게 만들어주지만, 유클리드 호제법의 원리를 이해하는 데는 첫 번째 방법이 더 도움이 될 수 있습니다.
#
# ==================================================
# 예제 6: 창의적 콘텐츠 생성
# ==================================================

# %%
# 창의적 생성용 높은 temperature
llm_creative = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash-lite",
    temperature=0.9
)

creative_prompt = ChatPromptTemplate.from_template(
    "{topic}에 대한 창의적인 {content_type}를 {style} 스타일로 작성하세요."
)

creative_chain = creative_prompt | llm_creative | StrOutputParser()
creative_result = creative_chain.invoke({
    "topic": "미래의 교통수단",
    "content_type": "아이디어",
    "style": "혁신적이고 실현 가능한"
})
print("창의적 아이디어:", creative_result)

print("\n" + "=" * 50)
print("Gemini 모델 옵션")
print("=" * 50)
print("• gemini-1.5-flash: 빠른 응답, 일반 작업")
print("• gemini-1.5-pro: 정확한 분석, 복잡한 추론")
print("• gemini-pro-vision: 이미지 처리 가능")
print("• temperature: 0.1(정확) ~ 0.9(창의적)")
print("=" * 50)
# Out:
# 창의적 아이디어: ## 미래의 교통수단: 혁신적인 아이디어
#
# 미래의 교통수단은 단순히 이동을 넘어, 삶의 질을 향상시키고 지속 가능한 환경을 구축하는 데 기여해야 합니다. 여기에 혁신적이고 실현 가능한 미래 교통수단 아이디어들을 제시합니다.
#
# ---
#
# ### 1. 개인 맞춤형 자율 모듈형 교통 시스템 (Personalized Autonomous Modular Transit System, P.A.M.T.S.)
#
# **핵심 아이디어:** 사용자의 필요와 상황에 맞춰 즉각적으로 형태와 기능을 변환하는 개인 맞춤형 모듈형 교통 시스템.
#
# **상세 설명:**
#
# *   **모듈화된 캡슐:** P.A.M.T.S.는 다양한 크기와 기능을 가진 모듈형 캡슐로 구성됩니다. 예를 들어, 1인용 출퇴근 캡슐, 가족용 여행 캡슐, 물류 운송 캡슐 등이 있습니다.
# *   **자율 주행 및 연결:** 각 캡슐은 최첨단 자율 주행 기술을 탑재하며, 도로, 지하, 공중 등 다양한 경로를 효율적으로 탐색합니다. 캡슐들은 서로 연결되어 기차처럼 운행되거나, 독립적으로 이동할 수 있습니다.
# *   **스마트 팝업 스테이션:** 도심 곳곳에 지능형 팝업 스테이션이 설치됩니다. 사용자는 스마트폰 앱을 통해 원하는 캡슐을 호출하면, 스테이션에서 해당 캡슐이 즉시 연결되어 탑승합니다.
# *   **맞춤형 경험:** 캡슐 내부는 사용자의 선호도에 따라 조명, 온도, 엔터테인먼트 시스템 등이 조절됩니다. 업무, 휴식, 엔터테인먼트 등 다양한 목적으로 활용 가능합니다.
# *   **에너지 효율:** 태양광, 수소 연료 전지 등 친환경 에너지원을 활용하며, 모듈 간 연결 시 발생하는 회생 제동 에너지를 재활용합니다.
#
# **혁신성 및 실현 가능성:**
#
# *   **혁신성:** 단순한 이동 수단을 넘어 사용자의 라이프스타일에 완벽하게 통합되는 개인 맞춤형 경험을 제공합니다. 기존의 대중교통과 개인 차량의 장점을 결합하고, 필요에 따라 형태를 변환하는 유연성이 혁신적입니다.
# *   **실현 가능성:** 자율 주행 기술, 모듈화 기술, 스마트 시티 인프라 구축 등의 발전 속도를 고려할 때, 10-20년 내 실현 가능성이 높습니다. 초기에는 특정 도시 구간에서 시범 운영 후 점차 확대될 수 있습니다.
#
# ---
#
# ### 2. 초고속 진공 튜브 이동 네트워크 (Hyper-Velocity Vacuum Tube Transit, H.V.V.T.)
#
# **핵심 아이디어:** 지상 및 지하에 건설된 진공 튜브 안에서 자기 부상 열차가 초고속으로 이동하며 도시 간, 국가 간 이동 시간을 획기적으로 단축하는 시스템.
#
# **상세 설명:**
#
# *   **진공 튜브:** 공기 저항을 최소화하기 위해 거의 완벽한 진공 상태의 튜브를 건설합니다.
# *   **자기 부상 기술:** 튜브 내에서 자기 부상 기술을 이용하여 열차가 떠서 이동하며, 마찰을 없애 에너지 효율성을 극대화합니다.
# *   **캡슐형 열차:** 각 캡슐형 열차는 최대 수백 km/h의 속도로 이동하며, 목적지 도착 시 다른 튜브로 전환하거나 역에 정차합니다.
# *   **지능형 경로 관리:** AI 기반 시스템이 열차의 속도, 경로, 간격을 실시간으로 최적화하여 안전하고 효율적인 운행을 보장합니다.
# *   **지하 및 해저 터널:** 도심 교통 체증을 피하고 지리적 제약을 극복하기 위해 지하 및 해저 터널을 적극 활용합니다.
#
# **혁신성 및 실현 가능성:**
#
# *   **혁신성:** 현재의 고속철도보다 훨씬 빠른 속도로 도시 간 이동을 가능하게 하여, 지구촌을 더욱 가깝게 만듭니다. 장거리 이동 시간을 비행기 수준으로 단축시키면서도, 환경 오염을 최소화합니다.
# *   **실현 가능성:** 이미 일부 구간에서 시범 운영 중인 하이퍼루프(Hyperloop) 기술을 기반으로 하며, 대규모 투자를 통해 전 세계적인 네트워크 구축이 가능합니다. 기술적 난이도는 높지만, 장기적인 관점에서 실현 가능한 프로젝트입니다.
#
# ---
#
# ### 3. 하늘을 나는 친환경 개인 이동체 (Eco-Friendly Aerial Personal Mobility, E.A.P.M.)
#
# **핵심 아이디어:** 소음과 배출가스가 없는 개인용 비행체로, 도심 내 이동 및 단거리 항공 이동을 혁신하는 시스템.
#
# **상세 설명:**
#
# *   **전기 수직 이착륙 (eVTOL) 기술:** 친환경 전기 모터를 기반으로 소음과 진동을 최소화한 eVTOL 기술을 활용합니다.
# *   **자율 비행 및 충돌 방지:** AI 기반 자율 비행 시스템과 첨단 센서 기술을 통해 안전하고 효율적인 비행을 지원하며, 다른 비행체 및 장애물과의 충돌을 방지합니다.
# *   **개인 맞춤형 디자인:** 1인승부터 4인승까지 다양한 크기의 디자인이 가능하며, 사용자의 취향에 맞춰 내부 인테리어를 커스터마이징할 수 있습니다.
# *   **스마트 버티포트 (Vertiport):** 도심 곳곳에 설치된 소규모 버티포트는 eVTOL의 이착륙 및 충전 스테이션 역할을 합니다.
# *   **공중 도로망:** AI가 관리하는 지정된 공중 도로망을 통해 체계적인 비행 경로를 유지하며, 교통 흐름을 최적화합니다.
#
# **혁신성 및 실현 가능성:**
#
# *   **혁신성:** 도심 내 지상 교통 체증을 완전히 해소하고, 이동 시간을 획기적으로 단축시킵니다. 개인의 자유로운 이동성을 극대화하며, 새로운 도시 풍경을 만들어냅니다.
# *   **실현 가능성:** eVTOL 기술은 빠르게 발전하고 있으며, 이미 많은 기업들이 상용화를 준비하고 있습니다. 항공 규제, 안전성 확보, 소음 문제 해결 등의 과제가 남아있지만, 5-15년 내에 상용화될 가능성이 높습니다.
#
# ---
#
# ### 4. 생체 에너지 활용 이동 보조 장치 (Bio-Energy Assisted Mobility Aid, B.E.A.M.A.)
#
# **핵심 아이디어:** 사용자의 생체 에너지를 활용하여 이동을 보조하고, 동시에 개인의 건강 상태를 모니터링하는 웨어러블 또는 삽입형 장치.
#
# **상세 설명:**
#
# *   **생체 에너지 수확:** 사용자의 움직임, 체온, 심장 박동 등에서 발생하는 미세한 에너지를 수확하여 장치 구동에 사용합니다.
# *   **스마트 이동 보조:** 보행 시 발생하는 에너지를 활용하여 휠체어, 외골격 슈트, 또는 스마트 스쿠터 등을 보조적으로 구동시켜 이동을 돕습니다.
# *   **건강 모니터링:** 실시간으로 심박수, 혈압, 활동량, 수면 패턴 등 건강 데이터를 수집하고 분석하여 개인 맞춤형 건강 정보를 제공합니다.
# *   **에너지 공유 및 저장:** 수확된 에너지는 장치 구동 외에도 휴대폰 충전, 개인 조명 등 소규모 전자기기에도 활용될 수 있습니다.
# *   **인체 삽입형 옵션:** 미래에는 인체에 삽입 가능한 소형 칩 형태로 개발되어, 더욱 자연스럽고 지속적인 에너지 수확 및 건강 관리를 지원할 수 있습니다.
#
# **혁신성 및 실현 가능성:**
#
# *   **혁신성:** 지속 가능한 에너지 활용의 새로운 패러다임을 제시하며, 이동 약자를 포함한 모든 사람들에게 독립적이고 건강한 이동성을 제공합니다. 개인의 건강과 이동성을 통합적으로 관리하는 혁신적인 접근 방식입니다.
# *   **실현 가능성:** 생체 에너지 수확 기술은 아직 초기 단계이지만, 나노 기술, 웨어러블 기술, 바이오 센서 기술의 발전을 통해 15-25년 내에 현실화될 가능성이 있습니다. 초기에는 보조 장치 형태로, 점차 발전하여 다양한 형태로 적용될 것입니다.
#
# ---
#
# 이러한 아이디어들은 미래 교통 시스템이 단순히 이동 수단을 넘어, 지속 가능하고, 개인에게 최적화되며, 삶의 질을 향상시키는 방향으로 발전할 것임을 보여줍니다. 이러한 혁신적인 미래 교통수단들이 현실화된다면, 우리는 더욱 편리하고, 안전하며, 건강한 삶을 누릴 수 있을 것입니다.
#
# ==================================================
# Gemini 모델 옵션
# ==================================================
# • gemini-1.5-flash: 빠른 응답, 일반 작업
# • gemini-1.5-pro: 정확한 분석, 복잡한 추론
# • gemini-pro-vision: 이미지 처리 가능
# • temperature: 0.1(정확) ~ 0.9(창의적)
# ==================================================
