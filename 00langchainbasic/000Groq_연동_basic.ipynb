# %%
print("Hello LangChain!!")
# Out:
# Hello LangChain!!

# %%
import os
from dotenv import load_dotenv

#load_dotenv(dotenv_path='.env')
load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
print(OPENAI_API_KEY[:10])
# Out:
# gsk_DICKFK

# %%
from langchain_core.prompts import ChatPromptTemplate

# prompt
prompt = ChatPromptTemplate.from_messages(
    [ ("system", "당신은 개발자입니다.") , 
     ("user", "{input}") ]
)
print(type(prompt))
print(prompt)
# Out:
# <class 'langchain_core.prompts.chat.ChatPromptTemplate'>
# input_variables=['input'] input_types={} partial_variables={} messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='당신은 개발자입니다.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})]

# %%
prompt_text = prompt.format(input="파이썬은 무엇인가요? 자세하게 설명해주세요")
print(type(prompt_text))
print(prompt_text)
# Out:
# <class 'str'>
# System: 당신은 개발자입니다.
# Human: 파이썬은 무엇인가요? 자세하게 설명해주세요

# %%
from langchain_openai import ChatOpenAI 

#llm = ChatOpenAI(api_key=OPENAI_API_KEY, model_name="gpt-3.5-turbo-0125")

# Groq API를 사용하는 ChatOpenAI 인스턴스 생성
llm = ChatOpenAI(
    #api_key=OPENAI_API_KEY,
    base_url="https://api.groq.com/openai/v1",  # Groq API 엔드포인트
    #model="meta-llama/llama-4-scout-17b-16e-instruct",
    model="moonshotai/kimi-k2-instruct-0905",
    # model="openai/gpt-oss-120b",
    temperature=0.7
)
print(type(llm))
print(llm)
# Out:
# <class 'langchain_openai.chat_models.base.ChatOpenAI'>
# profile={} client=<openai.resources.chat.completions.completions.Completions object at 0x0000012E5A59AF60> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x0000012E5AC61B50> root_client=<openai.OpenAI object at 0x0000012E5A2F2150> root_async_client=<openai.AsyncOpenAI object at 0x0000012E5AC65550> model_name='moonshotai/kimi-k2-instruct-0905' temperature=0.7 model_kwargs={} openai_api_key=SecretStr('**********') openai_api_base='https://api.groq.com/openai/v1'

# %%
try:
    response = llm.invoke(prompt_text)
    print(type(response))
    print("응답:", response.content)
except Exception as e:
    print(f"오류 발생: {e}")
# Out:
# <class 'langchain_core.messages.ai.AIMessage'>
# 응답: 파이썬(Python)은 1991년 네덜란드의 개빈 반 로섬(Guido van Rossum)이 발표한 고급 프로그래밍 언어입니다. “코드는 읽히는 것(readability)”을 철학으로 삼아, C/C++이나 Java에 비해 문법이 간결하고 배우기 쉽게 설계되었습니다. 아래에 파이썬의 정의, 특징, 동작 원리, 생태계, 활용 분야, 한계까지 한눈에 정리해 드리겠습니다.
#
# ────────────────────────────────────────
# 1. 파이썬이란 무엇인가?
# ────────────────────────────────────────
# • 인터프리터형(Interpreter) 언어
#   소스 코드(.py)를 한 줄씩 해석해 즉시 실행합니다. 컴파일 언어처럼 전체를 빌드할 필요가 없어 “스크립트 언어”라고도 부릅니다.
# • 객체지향·절차지향·함수형을 모두 지원하는 멀티패러다임 언어
# • 크로스플랫폼: Windows·macOS·Linux·임베디드·모바일(Chaquopy, PyDroid 등)
# • 오픈소스·무료(Python Software Foundation 라이선스)
# • 버전: 3.x가 현재 표준(2020년 1월 이후 Python 2 공식 지원 종료)
#
# ────────────────────────────────────────
# 2. 핵심 철학(The Zen of Python)
# ────────────────────────────────────────
# `import this`를 실행하면 19가지 “파이썬 다움”이 나타납니다. 대표 문구:
# “Beautiful is better than ugly.
# Simple is better than complex.
# Readability counts.”
# → 이 때문에 비전공자나 연구자도 짧은 코드로 아이디어를 빠르게 검증할 수 있습니다.
#
# ────────────────────────────────────────
# 3. 왜 짧고 읽기 쉬운가?
# ────────────────────────────────────────
# 1) 들여쓰기(indent)로 블록 구분
#    if, for, 함수, 클래스 등 “{ }” 대신 들여쓰기 4칸으로 범위를 정해視覽적 clutter 제거
# 2) 동적 타이핑(Dynamic typing)
#    변수 선언 없이 `x = 3` 한 줄로 정수형 변수 생성 → 생산성 ↑
# 3) 강력한 내장 자료형
#    list, dict, set, tuple, str 등 기본 자료구조가 표준으로 제공
# 4) 풍부한 문법 설탕(syntax sugar)
#    리스트 컴프리헨션 `[x**2 for x in range(10) if x%2]`
#    with문, 데코레이터, 제너레이터, *args/**kwargs 등으로 보일러플레이트 최소화
#
# ────────────────────────────────────────
# 4. 실행 모델: 인터프리터 + 가상머신
# ────────────────────────────────────────
# 1) 소스코드 → 바이트코드(.pyc) 컴파일
#    CPython(공식 구현체)은 내부적으로 “컴파일러”를 거쳐 플랫폼 독립적인 바이트코드를 생성합니다.
# 2) PVM(Python Virtual Machine)이 바이트코드를 실행
#    .pyc 파일은 __pycache__ 폴더에 캐싱되어 매번 파싱하지 않아도 됨.
# 3) GIL(Global Interpreter Lock)
#    CPython은 스레드 하나만 파이썬 객체에 접근 가능 → CPU-bound 멀티스레드 성능 한계(대안: multiprocessing, PyPy, Jython, Cython, Rust/C++ 확장 등)
#
# ────────────────────────────────────────
# 5. 표준 라이브러리 & 외부 생태계
# ────────────────────────────────────────
# • 표준 라이브러리만도 200개 이상의 내장 모듈
#   os, sys, datetime, re, json, pathlib, asyncio, concurrent.futures …
# • PyPI(pip) 45만+ 패키지
#   데이터: NumPy, pandas, SciPy
#   머신러닝: scikit-learn, TensorFlow, PyTorch, Hugging Face transformers
#   웹: Django, Flask, FastAPI
#   자동화: requests, BeautifulSoup, Selenium, PyAutoGUI
#   GUI: Tkinter(내장), PyQt, Kivy
#   게임: pygame, Panda3D
#   과학·시각화: Matplotlib, Seaborn, Plotly, Jupyter, Spyder
#   패키지 관리: pip, venv, poetry, conda, pipenv
#
# ────────────────────────────────────────
# 6. 주요 활용 분야
# ────────────────────────────────────────
# • 데이터 분석·빅데이터(판다스, Spark PySpark)
# • 인공지능·딥러닝(텐서플로·파이토치)
# • 웹 서버(Django/Flask/FastAPI)
# • DevOps·자동화 스크립트(서버 배포, CI/CD, 크롤링)
# • 업무 자동화(Excel, PDF, 메일, GUI 로봇)
# • 사이버 보안(스크립팅, 포렌식, Exploit PoC)
# • 금융(트레이딩 봇, 백테스트, QuantLib)
# • 생명과학·바이오인포매틱스(BioPython)
# • 교육(코딩 입문, 대학교 프로그래밍 기초)
# • 임베디드·IoT(MicroPython, CircuitPython)
#
# ────────────────────────────────────────
# 7. 단점 & 한계
# ────────────────────────────────────────
# • 실행 속도: C/C++ 대비 10~100배 느릴 수 있음(계산 집중 코드는 Cython, Numba, Rust 확장)
# • 모바일 네이티브: Kotlin/Swift 대비 생태계 부족(Kivy·BeeWare는 한계 있음)
# • GIL로 인한 멀티스레드 CPU-bound 한계
# • 런타임 에러 가능성: 동적 타이핑으로 컴파일 타임 검증 약함(타입 힌트·mypy·pydantic으로 보완)
# • 패키지 의존성 지옥: 버전 충돌, pyenv·poetry로 관리 필요
#
# ────────────────────────────────────────
# 8. 설치 및 첫걸음
# ────────────────────────────────────────
# 1) 공식 사이트 python.org 에서 3.12.x 다운로드
# 2) Windows 체크: “Add Python to PATH” 선택
# 3) 터미널에서
#    $ python -m venv .venv
#    $ source .venv/bin/activate  # Win: .venv\Scripts\activate
#    (.venv) $ pip install numpy pandas jupyter
#    (.venv) $ jupyter lab
# 4) 첫 스크립트 hello.py
#    print(“Hello, Python!”)
# 5) 실행
#    (.venv) $ python hello.py
#
# ────────────────────────────────────────
# 9. 요약
# ────────────────────────────────────────
# 파이썬은 “생산성 최우선” 설계로 문법이 단순해 초보자가 문법에 얽매이지 않고 문제 해결에 집중할 수 있고, 방대한 표준·외부 라이브러리가 있어 “혼자 끝내는(One-man army)” 스크립팅부터 웹·AI·빅데이터까지 폭넓게 쓰입니다. 속도나 모바일, 멀티스레딩 한계는 대체 기술·확장으로 보완할 수 있으며, 여전히 가장 빠르게 성장하는 언어 중 하나입니다.

# %% [markdown]
# # LCEL
# ### Prompt + LLM 모델 + OutputParser

# %%
from langchain_core.output_parsers import StrOutputParser

output_parser = StrOutputParser()

# %%
chain = prompt | llm | output_parser
print(type(chain))
print(chain)
# Out:
# <class 'langchain_core.runnables.base.RunnableSequence'>
# first=ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='당신은 개발자입니다.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})]) middle=[ChatOpenAI(profile={}, client=<openai.resources.chat.completions.completions.Completions object at 0x0000012E5A59AF60>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x0000012E5AC61B50>, root_client=<openai.OpenAI object at 0x0000012E5A2F2150>, root_async_client=<openai.AsyncOpenAI object at 0x0000012E5AC65550>, model_name='moonshotai/kimi-k2-instruct-0905', temperature=0.7, model_kwargs={}, openai_api_key=SecretStr('**********'), openai_api_base='https://api.groq.com/openai/v1')] last=StrOutputParser()

# %%
response = chain.invoke({"input":"LangChain은 무엇인가요?"})

# %%
print(type(response))
print(response)
# Out:
# <class 'str'>
# LangChain은 “거대언어모델(LLM)을 애플리케이션에 쉽게 연결(chain)해 주는” 오픈소스 프레임워크입니다.
# 핵심 목표는 “LLM 한 대만으로는 부족한” 실전 수준의 AI 기능을 1) 데이터·API·툴과 연결하고 2) 여러 단계의 추론·행동을 반복할 수 있도록 만들어 주는 것입니다.
#
# 1. 왜 나왔나?
#    - LLM은 지식이 고정돼 있고, 외부 데이터·서비스에 직접 접근할 수 없다.
#    - 복잡한 업무(질의→검색→추출→요약→액션)를 한 번에 끝내지 못한다.
#    → 이를 “chain”으로 엮어주는 추상화 계층이 필요했다.
#
# 2. 핵심 개념 3줄 요약
#    1. Component: LLM, 프롬프트 템플릿, 출력 파서, 벡터스토어, retriever, memory 등 “레고 블록”
#    2. Chain: Component를 조합한 파이프라인(예: 질문→유사도검색→LLM→답변)
#    3. Agent: Chain에 “행동(도구 호출)” 능력을 추가. 생각→행동→관찰→생각 … 반복
#
# 3. 대표 모듈
#    - langchain-core: 인터페이스 정의(범용)
#    - langchain-community: 수백 개의 통합(OpenAI, HuggingFace, Google, AWS, Azure, Snowflake, Slack, SQL DB …)
#    - langchain(=langchain-core + community): 레거시 통합(신규 기능은 종종 community로 이동)
#    - langgraph: DAG·상태머신 기반 복잡한 워크플로우
#    - langserve: Chain/Agent를 자동으로 REST API로 배포
#    - LangSmith: 실험·추적·모니터링 플랫폼(별도 SaaS)
#
# 4. 실제 쓰는 방식
# ```python
# from langchain_community.vectorstores import FAISS
# from langchain_openai import OpenAIEmbeddings, ChatOpenAI
# from langchain.chains import ConversationalRetrievalChain
# from langchain.memory import ConversationBufferMemory
#
# embeddings = OpenAIEmbeddings()
# vectorstore = FAISS.from_texts(["LangChain은 …", "LLM은 …"], embeddings)
# memory = ConversationBufferMemory(memory_key="chat_history", return_messages=True)
# qa = ConversationalRetrievalChain.from_llm(
#         llm=ChatOpenAI(model="gpt-4-turbo"),
#         retriever=vectorstore.as_retriever(),
#         memory=memory)
# print(qa.invoke("LangChain에 대해 설명해줘"))
# ```
# → 문서 기반 대화봇 완성.
#
# 5. Agent 예시
# ```python
# from langchain.agents import AgentExecutor, create_openai_functions_agent
# from langchain_openai import ChatOpenAI
# from langchain.tools import Tool
# from langchain import hub
#
# tools = [Tool(
#     name="현재_날씨",
#     func=lambda loc: f"{loc} 흐림",
#     description="도시명을 받아 날씨를 반환")]
# agent = create_openai_functions_agent(ChatOpenAI(), tools, hub.pull("hwchase17/openai-functions-agent"))
# print(AgentExecutor(agent=agent, tools=tools).invoke("서울 날씨 알려줘"))
# ```
#
# 6. LangChain의 장점
#    - 파이썬·JS·Java·Go·Rust 지원
#    - 400+ 공식 통합, 1,000+ 커뮤니티 통합
#    - LCEL(LangChain Expression Language)로 선언적 파이프라인 작성
#    - 배포·모니터링까지 한 방에(LangSmith, LangServe)
#
# 7. 단점 / 고려점
#    - 추상화가 두꺼워 내부 동작 파악이 어려울 수 있음
#    - 버전 업그레이드가 빨라 API 변동 잦음
#    - 단순 LLM 호출에는 오버헤드일 수 있음 → “LangChain이 꼭 필요한가?”를 먼저 판단
#
# 8. LangChain이 아닌 대안
#    - LlamaIndex(검색·RAG 특화)
#    - Haystack, Semantic Kernel, CrewAI, Autogen, MS Copilot Studio 등
#
# 요약: LangChain은 “LLM + 외부 데이터 + 도구 + 추론 루프”를 쉽게 엮어주는 “플러그 앤 플레이” 프레임워크로, 대화형 검색 시스템, 자동화 에이전트, 보고서 생성 봇 등을 빠르게 만들고 싶을 때 가장 많이 쓰이는 오픈소스 도구입니다.
